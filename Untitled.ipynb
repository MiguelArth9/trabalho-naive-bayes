# %%
pip install scikit-learn pandas matplotlib
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('pip', 'install scikit-learn pandas matplotlib')
#
# OSError: Not available

# %%
# %pip install scikit-learn pandas matplotlib
